# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import cv2
import mediapipe as mp

# %%
cap = cv2.VideoCapture(0)
mpPose = mp.solutions.pose
pose = mpPose.Pose()
mpDraw = mp.solutions.drawing_utils

while True:
    succes, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    result = pose.process(imgRGB) 
    
    if result.pose_landmarks:
        mpDraw.draw_landmarks(img, result.pose_landmarks, mpPose.POSE_CONNECTIONS) 
    
    cv2.imshow("Image", img)
    if cv2.waitKey(1) & 0xFF == 27:  # Presionar 'Esc' para salir
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# UBICAR UN PUNTO CONCRETO:

# %%
cap = cv2.VideoCapture(0)
mpPose = mp.solutions.pose
pose = mpPose.Pose()
mpDraw = mp.solutions.drawing_utils

while True:
    succes, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    result = pose.process(imgRGB) 
    
    if result.pose_landmarks:
        mpDraw.draw_landmarks(img, result.pose_landmarks, mpPose.POSE_CONNECTIONS) 
        
        for id, lm in enumerate(result.pose_landmarks.landmark): # Nos ayudara a identificar cada uno de los puntos (landmarks)
                # Print de coordenadas de cada uno de los landmarks
                print(f'id: {id}\n{lm}') 
                
                # Print de coordenadas de cada uno de los puntos de la mano en pixeles
                h, w, c = img.shape
                centerX, centerY = int(lm.x*w), int(lm.y*h)
                print(f'id: {id}\nX:{centerX} | Y:{centerY}')
                print("-----")
                
                # Podemos usar estas coordenadas como queramos
                # Estamos haciendo que el punto de la nariz sea morado y mas grande
                if id == 0:
                    cv2.circle(img, (centerX, centerY), 10, (255,0,255), cv2.FILLED)
    
    cv2.imshow("Image", img)
    if cv2.waitKey(1) & 0xFF == 27:  # Presionar 'Esc' para salir
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# id: 0
# x: 0.519509673
# y: 0.594658
# z: -1.08303094
# visibility: 0.999894619
#
# id: 0
# X:332 | Y:285
# -----
# id: 1
# x: 0.566155195
# y: 0.502988219
# z: -1.03928757
# visibility: 0.999739826
#
# id: 1
# X:362 | Y:241
# -----
# id: 2
# x: 0.592079639
# y: 0.501604795
# z: -1.03920639
# visibility: 0.999747
#
# id: 2
# X:378 | Y:240
# -----
# id: 3
# x: 0.61367029
# y: 0.50089
# z: -1.03957582
# visibility: 0.99971503
#
# id: 3
# X:392 | Y:240
# -----
# id: 4
# x: 0.480861723
# y: 0.50982511
# z: -1.01587439
# visibility: 0.999768198
#
# id: 4
# X:307 | Y:244
# -----
# id: 5
# x: 0.455222428
# y: 0.51029706
# z: -1.01448882
# visibility: 0.99978441
#
# id: 5
# X:291 | Y:244
# -----
# id: 6
# x: 0.436213583
# y: 0.51134336
# z: -1.0149312
# visibility: 0.999795139
#
# id: 6
# X:279 | Y:245
# -----
# id: 7
# x: 0.656621814
# y: 0.534856439
# z: -0.612980843
# visibility: 0.999702871
#
# id: 7
# X:420 | Y:256
# -----
# id: 8
# x: 0.417280734
# y: 0.545503855
# z: -0.472800493
# ...
